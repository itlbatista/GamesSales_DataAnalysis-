# %% [markdown]
# <h1>Venda de jogos de videogames na história</h1>
# <br>
# Este projeto foi criado por <b>Lucas Thiago Batista</b>. Aqui irei realizar algumas análises sobre os dados encontrados <a href='https://drive.google.com/open?id=1WIvQvu_fqd5RBUFZfrrN9s0hNbMrxaGP'> neste dataset </a>.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#Leitura do arquivo
videogames = pd.read_csv('vgsales.csv')

# %%
#Exibindo as 10 prmeiros linhdas do arquivo usando a função head()
videogames.head(20)
# Out:
#     Ranking                                          Nome Plataforma     Ano  \
# 0         1                                    Wii Sports        Wii  2006.0
# 1         2                             Super Mario Bros.        NES  1985.0
# 2         3                                Mario Kart Wii        Wii  2008.0
# 3         4                             Wii Sports Resort        Wii  2009.0
# 4         5                      Pokemon Red/Pokemon Blue         GB  1996.0
# 5         6                                        Tetris         GB  1989.0
# 6         7                         New Super Mario Bros.         DS  2006.0
# 7         8                                      Wii Play        Wii  2006.0
# 8         9                     New Super Mario Bros. Wii        Wii  2009.0
# 9        10                                     Duck Hunt        NES  1984.0
# 10       11                                    Nintendogs         DS  2005.0
# ...

# %%
#Resumo de Informações em todas as colunas
videogames.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#Tipo de dado de cada colunas
videogames.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#Quantidade de Linhas e Colunas do dataset
videogames.shape
# Out:
# (16598, 11)

# %%
#Renomeando as colunas do dataset
videogames.columns = ['Ranking','Nome','Plataforma','Ano','Genero','Editora','Vendas NA','Vendas EUA','Vendas JP','Outras Vendas','Vendas Global']

# %%
videogames.head(10)
# Out:
#    Ranking                       Nome Plataforma     Ano        Genero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#     Editora  Vendas NA  Vendas EUA  Vendas JP  Outras Vendas  Vendas Global
# 0  Nintendo      41.49       29.02       3.77           8.46          82.74
# ...

# %%
#listar registros em que o Ano está null Not a Number
videogames[videogames['Ano'].isnull()].head()
# Out:
#      Ranking                        Nome Plataforma  Ano    Genero  \
# 179      180             Madden NFL 2004        PS2  NaN    Sports
# 377      378            FIFA Soccer 2004        PS2  NaN    Sports
# 431      432  LEGO Batman: The Videogame        Wii  NaN    Action
# 470      471  wwe Smackdown vs. Raw 2006        PS2  NaN  Fighting
# 607      608              Space Invaders       2600  NaN   Shooter
#
#                                     Editora  Vendas NA  Vendas EUA  Vendas JP  \
# 179                         Electronic Arts       4.26        0.26       0.01
# 377                         Electronic Arts       0.59        2.36       0.04
# 431  Warner Bros. Interactive Entertainment       1.86        1.02       0.00
# 470                                     NaN       1.57        1.02       0.00
# 607                                   Atari       2.36        0.14       0.00
#
#      Outras Vendas  Vendas Glogal
# 179           0.71           5.23
# ...

# %%
#Mostra quantos jogos foram lançados por plataforma, semelhante ao group by
videogames['Plataforma'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Plataforma, dtype: int64

# %%
titulos_lancados = videogames['Plataforma'].value_counts()
titulos_lancados.plot()

#mas eu tambem poderia fazer sem criar a variável videogames['Plataforma'].value_counts().plot()

# %%
#Criando um gráfico utilizando apenas uma linha de código 
videogames['Plataforma'].value_counts().head(10).plot(kind = 'bar', figsize = (11,5), grid = False, rot = 0, color = 'green')
#chamei a variável que acessa o dataset, acessei o top 10 por plata forma e criei um grafico usando a funcao plot com seus atributos

#Enfeitando o gráfico. Abaixo, definimos um título
plt.title('Os 10 Videogames com mais títulos lançados')
plt.xlabel('Videogames') #nomeando o eixo X
plt.ylabel('Qtde de jogos lancados') #nomeando o eixo y
plt.show() #para exibir  gráfico

# %%
videogames['Plataforma'].value_counts().head(10).plot(kind = 'bar', figsize = (11,5), grid = False, rot = 0, color = 'green')

plt.title('Os 10 videogames com mais titulos lancados');
plt.xlabel('Videogames')
plt.ylabel('Qtde')
plt.show()

# %%
top_10_vendidos = videogames[['Nome','Vendas Global']].head(10).set_index('Nome').sort_values('Vendas Global', ascending=True)
top_10_vendidos.plot(kind='barh', figsize=(11,7), grid=False, color='darkred', legend=False)


plt.title('Os 10 Jogos mais vendidos do mundo')
plt.xlabel('Total de vendas (em milhoes de dolares)')
plt.show()

# %%
crosstab_vg = pd.crosstab(videogames['Plataforma'], videogames['Genero'])
crosstab_vg.head()
# Out:
# Genero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Genero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   86        7          30      26        15
# DC                     4        3           1      10         0
# DS                   200       42         285     148        79

# %%
crosstab_vg['Total'] = crosstab_vg.sum(axis=1)
crosstab_vg.head()
# Out:
# Genero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Genero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# 2600                   0       24           1      12         0    133
# 3DO                    0        0           1       0         0      3
# 3DS                   86        7          30      26        15    509
# DC                     4        3           1      10         0     52
# DS                   200       42         285     148        79   2163

# %%
top10_platforms = crosstab_vg[crosstab_vg['Total'] > 1000].sort_values('Total', ascending = False)
top10_final = top10_platforms.append(pd.DataFrame(top10_platforms.sum(), columns=['total']).T, ignore_index=False)

sns.set(font_scale=1) #tamanho da fonte do grafico
plt.figure(figsize=(18, 9)) #tamanho da figura do grafico
sns.heatmap(top10_final, annot=True, vmax=top10_final.loc[:'PS', :'Strategy'].values.max(), vmin=top10_final.loc[:, :'Strategy'].values.min(), fmt='d')
plt.xlabel('Genero')
plt.ylabel('Console')
plt.title('Quantidade de titulos por genero e console')
plt.show()
